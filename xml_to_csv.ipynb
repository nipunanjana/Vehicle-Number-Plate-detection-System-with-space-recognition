# %%
import pandas as pd
import xml.etree.ElementTree as xet

# %%
from glob import glob

# %%
path = glob('./train/*.xml')
path
# Out:
# ['./train\\1.xml',
#  './train\\10.xml',
#  './train\\100.xml',
#  './train\\11.xml',
#  './train\\12.xml',
#  './train\\13.xml',
#  './train\\14.xml',
#  './train\\15.xml',
#  './train\\16.xml',
#  './train\\17.xml',
#  './train\\18.xml',
#  './train\\19.xml',
#  './train\\2.xml',
#  './train\\20.xml',
#  './train\\21.xml',
#  './train\\22.xml',
#  './train\\23.xml',
#  './train\\24.xml',
#  './train\\25.xml',
#  './train\\26.xml',
#  './train\\27.xml',
#  './train\\28.xml',
#  './train\\29.xml',
#  './train\\30.xml',
#  './train\\31.xml',
#  './train\\32.xml',
#  './train\\33.xml',
#  './train\\34.xml',
#  './train\\35.xml',
#  './train\\36.xml',
#  './train\\37.xml',
#  './train\\38.xml',
#  './train\\39.xml',
#  './train\\4.xml',
#  './train\\40.xml',
#  './train\\41.xml',
#  './train\\42.xml',
#  './train\\43.xml',
#  './train\\44.xml',
#  './train\\45.xml',
#  './train\\46.xml',
#  './train\\47.xml',
#  './train\\48.xml',
#  './train\\49.xml',
#  './train\\5.xml',
#  './train\\50.xml',
#  './train\\51.xml',
#  './train\\52.xml',
#  './train\\53.xml',
#  './train\\54.xml',
#  './train\\55.xml',
#  './train\\56.xml',
#  './train\\57.xml',
#  './train\\58.xml',
#  './train\\59.xml',
#  './train\\6.xml',
#  './train\\60.xml',
#  './train\\61.xml',
#  './train\\62.xml',
#  './train\\63.xml',
#  './train\\64.xml',
#  './train\\65.xml',
#  './train\\66.xml',
#  './train\\67.xml',
#  './train\\68.xml',
#  './train\\69.xml',
#  './train\\7.xml',
#  './train\\70.xml',
#  './train\\71.xml',
#  './train\\72.xml',
#  './train\\73.xml',
#  './train\\74.xml',
#  './train\\75.xml',
#  './train\\76.xml',
#  './train\\77.xml',
#  './train\\78.xml',
#  './train\\79.xml',
#  './train\\8.xml',
#  './train\\80.xml',
#  './train\\81.xml',
#  './train\\82.xml',
#  './train\\83.xml',
#  './train\\84.xml',
#  './train\\85.xml',
#  './train\\86.xml',
#  './train\\87.xml',
#  './train\\88.xml',
#  './train\\89.xml',
#  './train\\9.xml',
#  './train\\90.xml',
#  './train\\91.xml',
#  './train\\92.xml',
#  './train\\93.xml',
#  './train\\94.xml',
#  './train\\95.xml',
#  './train\\96.xml',
#  './train\\97.xml',
#  './train\\98.xml',
#  './train\\99.xml']

# %%
labels_dict = dict(filepath=[],xmin=[],xmax=[],ymin=[],ymax=[])
for filename in path:

    #filename = path[0]
    info = xet.parse(filename) 
    root = info.getroot()
    member_object = root.find('object')
    labels_info = member_object.find('bndbox')
    xmin= int(labels_info.find('xmin').text)
    xmax= int(labels_info.find('xmax').text)
    ymin= int(labels_info.find('ymin').text)
    ymax= int(labels_info.find('ymax').text)
    #print(xmin,xmax,ymin,ymax)
    labels_dict['filepath'].append(filename)
    labels_dict['xmin'].append(xmin)
    labels_dict['xmax'].append(xmax)
    labels_dict['ymin'].append(ymin)
    labels_dict['ymax'].append(ymax)

# %%
df = pd.DataFrame(labels_dict)
df
# Out:
#            filepath  xmin  xmax  ymin  ymax
# 0     ./train\1.xml   436   516   355   392
# 1    ./train\10.xml   245   312   666   712
# 2   ./train\100.xml   403   470   653   718
# 3    ./train\11.xml   204   379   516   556
# 4    ./train\12.xml   310   404   666   693
# ..              ...   ...   ...   ...   ...
# 94   ./train\95.xml   553   656   614   678
# 95   ./train\96.xml   413   473   718   758
# 96   ./train\97.xml   290   381   676   705
# 97   ./train\98.xml   294   381   654   713
# 98   ./train\99.xml    51   145   571   629
#
# [99 rows x 5 columns]

# %%
df.to_csv('labels.csv',index=False)
